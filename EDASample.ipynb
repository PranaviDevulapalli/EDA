# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/DELL/Downloads/HRDataset_v14.csv")

# %%
lev=data.head(5)

# %%
data.info()#It is used to summarise the data and give what is the datype of each variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
data.shape#It is used to specify no of columns and no of rows
# Out:
# (311, 36)

# %%
#barplot-gives the estimate of the central tendency with the height of each rectangle
#gives the relationship between categorical variable and numerical variable
res=sns.barplot(data=lev,x='Employee_Name',y='Salary',color='red')
plt.show()

# %%
#countplot
sns.countplot(x='Salary',data=lev,palette='Set1')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21776\2572342013.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Salary',data=lev,palette='Set1')
# <Axes: xlabel='Salary', ylabel='count'>

# %%
data.tail()
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 306      Woodson, Jason  10135          0                0         1
# 307  Ybarra, Catherine   10301          0                0         0
# 308    Zamora, Jennifer  10010          0                0         0
# 309         Zhou, Julia  10043          0                0         0
# 310       Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#         ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# ...

# %%
data.describe()#That summarises the centralTendancies of the dataset
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
data.columns#Gives the names of the columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
data.nunique()#method in pandas is used to count the number of unique values in each column of a DataFrame.

# %%
lev['EmpID'].unique()#it shows the unique value in that dataFra,e
# Out:
# array([10026, 10084, 10196, 10088, 10069], dtype=int64)

# %% [markdown]
# Cleaning the data-Check for the null values in any of these datasets

# %%
lev.isnull().sum()#in these columns there are no null values

# %% [markdown]
# Clearing Some of the columns

# %%
lo = lev.drop(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
                'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
                'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
                'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
                'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
                'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
                'PerformanceScore'], axis=1) 

lo
# Out:
#    EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 0              4.60                5                     0
# 1              4.96                3                     6
# 2              3.02                3                     0
# 3              4.84                5                     0
# 4              5.00                4                     0
#
#   LastPerformanceReview_Date  DaysLateLast30  Absences
# 0                  1/17/2019               0         1
# 1                  2/24/2016               0        17
# 2                  5/15/2012               0         3
# 3                   1/3/2019               0        15
# 4                   2/1/2016               0         2

# %% [markdown]
# Relationship analysis
# corelation matrix

# %%
lo.info()
re=lo.drop(['EngagementSurvey','LastPerformanceReview_Date'],axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EngagementSurvey            5 non-null      float64
#  1   EmpSatisfaction             5 non-null      int64
#  2   SpecialProjectsCount        5 non-null      int64
#  3   LastPerformanceReview_Date  5 non-null      object
#  4   DaysLateLast30              5 non-null      int64
#  5   Absences                    5 non-null      int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 372.0+ bytes

# %%
corion=re.corr()

# %% [markdown]
# sns.heatmap(corelation,xtixklabels=corelation.columns,yticklabels=corelation.columns),annot=True

# %%
\
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)
#
# NameError: name 'correlation' is not defined
